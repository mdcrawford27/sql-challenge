# %%
import pandas as pd

from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:postgres@localhost:5432/EmployeeDB')
connection = engine.connect()

# %%
titles = pd.read_sql('select * from titles', connection)
titles.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
employees = pd.read_sql('select * from employees', connection)
employees.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053        e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444        e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786        s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238        e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18

# %%
departments = pd.read_sql('select * from departments', connection)
departments.head()
# Out:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development

# %%
salaries = pd.read_sql('select * from salaries',connection)
salaries.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
dept_manager = pd.read_sql('select * from dept_manager',connection)
dept_manager.head()
# Out:
#   dept_no  emp_no
# 0    d001  110022
# 1    d001  110039
# 2    d002  110085
# 3    d002  110114
# 4    d003  110183

# %%
dept_emp = pd.read_sql('select * from dept_emp',connection)
dept_emp.head()
# Out:
#    emp_no dept_no
# 0   10001    d005
# 1   10002    d007
# 2   10003    d004
# 3   10004    d004
# 4   10005    d003

# %%
import matplotlib.pyplot as plt

# Create a histogram to visualize the most common salary ranges for employees.
employees_salaries = employees.merge(salaries, on='emp_no')
employees_salaries.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date  \
# 0  473302        s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053        e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444        e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786        s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238        e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18
#
#    salary
# 0   40000
# 1   53422
# 2   48973
# 3   40000
# 4   40000

# %%
employees_salaries.hist(column='salary')
plt.xlabel("Salary")
plt.ylabel("# of Employees")
# Out:
# Text(0, 0.5, '# of Employees')

# %%
# Create a bar chart of average salary by title.

employees_title_salaries = employees_salaries.merge(titles, left_on='emp_title_id', right_on='title_id')
employees_title_salaries.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name   last_name sex   hire_date  \
# 0  473302        s0001  1953-07-25    Hideyuki    Zallocco   M  1990-04-28
# 1  421786        s0001  1957-09-28       Xiong    Verhoeff   M  1987-11-26
# 2  273487        s0001  1957-04-14   Christoph     Parfitt   M  1991-06-28
# 3  246449        s0001  1958-03-23       Subbu  Bultermann   F  1988-03-25
# 4   48085        s0001  1964-01-19  Venkatesan        Gilg   M  1993-06-28
#
#    salary title_id  title
# 0   40000    s0001  Staff
# 1   40000    s0001  Staff
# 2   56087    s0001  Staff
# 3   87084    s0001  Staff
# 4   63016    s0001  Staff

# %%
titles_salaries = employees_title_salaries[["title","salary"]]
titles_salaries.head()
# Out:
#    title  salary
# 0  Staff   40000
# 1  Staff   40000
# 2  Staff   56087
# 3  Staff   87084
# 4  Staff   63016

# %%
avg_salary_title = titles_salaries.groupby(['title'])['salary'].mean().round(2)

# %%
avg_salary_title.plot.bar()
plt.xlabel("Title")
plt.ylabel("Average Salary")
# Out:
# Text(0, 0.5, 'Average Salary')
